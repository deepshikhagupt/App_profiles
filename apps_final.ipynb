# %% [markdown]
# ## Profitable App Profiles for the App Store and Google Play Markets
#
# Our aim in this project is to find mobile app profiles that are profitable for the App Store and Google Play markets. We're working as data analysts for a company that builds Android and iOS mobile apps, and our job is to enable our team of developers to make data-driven decisions with respect to the kind of apps they build.
#
# At our company, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. This means that our revenue for any given app is mostly influenced by the number of users that use our app. Our goal for this project is to analyze data to help our developers understand what kinds of apps are likely to attract more users.
#
#
#
# How do you visualize price distribution of paid apps ?
# How does price distribution get affected by category ?
# What about paid apps Vs Free apps ?
# Are paid apps good enough ?
# As the size of the app increases do they get pricier ?
# How are the apps distributed category wise ? can we split by paid category ?

# %% [markdown]
# ### Opening and Exploring the Data
#
# As of September 2018, there were approximately 2 million iOS apps available on the App Store, and 2.1 million Android apps on Google Play.
#
# Collecting data for over four million apps requires a significant amount of time and money, so we'll try to analyze a sample of data instead. To avoid spending resources with collecting new data ourselves, we should first try to see whether we can find any relevant existing data at no cost. Luckily, these are two data sets that seem suitable for our purpose:
#
# A data set containing data about approximately ten thousand Android apps from Google Play. You can download the data set directly from this [link](https://dq-content.s3.amazonaws.com/350/googleplaystore.csv).
#     A data set containing data about approximately seven thousand iOS apps from the App Store. You can download the data set directly from this [link](https://dq-content.s3.amazonaws.com/350/AppleStore.csv).

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
def open_dataset(file_name, header=True):        
    opened_file = open(file_name,encoding = 'utf-8')
    from csv import reader
    read_file = reader(opened_file)
    data = list(read_file)
    
    if header:
        return data[0],data[1:]
    else:
        return data

# %%
apple_header , apple = open_dataset("AppleStore.csv")
google_header , google = open_dataset("googleplaystore.csv")

# %%
explore_data(apple,0,4,True)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# Number of rows: 7197
# Number of columns: 16

# %%
explore_data(google,0,4,True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %%
apple_header
# Out:
# ['id',
#  'track_name',
#  'size_bytes',
#  'currency',
#  'price',
#  'rating_count_tot',
#  'rating_count_ver',
#  'user_rating',
#  'user_rating_ver',
#  'ver',
#  'cont_rating',
#  'prime_genre',
#  'sup_devices.num',
#  'ipadSc_urls.num',
#  'lang.num',
#  'vpp_lic']

# %%
google_header
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
len(google[10472])
# Out:
# 12

# %% [markdown]
# #### Check for missing values in the datasets

# %%
def missing_col(dataset):
    for each_row in dataset:
        if len(each_row) != len(dataset[0]):
            print(dataset.index(each_row))
            print(each_row)
            print('\n')

# %%
missing_col(google)
# Out:
# 10472
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %% [markdown]
# ##### Delete the missing data row

# %%
del google[10472]

# %% [markdown]
# #### Check duplicate entries

# %%
def duplicate_entries(dataset,index):
    duplicate_apps = []
    unique_apps = []
    for app in dataset:
        name = app[index]
        if name in unique_apps:
            duplicate_apps.append(name)
        else:
            unique_apps.append(name)
          
    return duplicate_apps , unique_apps
        
duplicate_google , unique_google = duplicate_entries(google,0)      
print('Number of duplicate apps:', len(duplicate_google))
print('\n')
print('Examples of duplicate apps:', duplicate_google[:15])
# Out:
# Number of duplicate apps: 1181
#
#
# Examples of duplicate apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software']

# %%
duplicate_apple , unique_apple = duplicate_entries(apple,0)
print('Number of duplicate apps:', len(duplicate_apple))
# Out:
# Number of duplicate apps: 0

# %%
reviews_max = {}
for each_row in google:
    name = each_row[0]
    n_reviews = float(each_row[3])
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
    elif name not in reviews_max:
        reviews_max[name] = n_reviews
        
        
print('Expected length:', len(google) - 1181)
print('Actual length:', len(reviews_max))
# Out:
# Expected length: 9659
# Actual length: 9659

# %% [markdown]
# #### Creating a new dataset without duplicate entries (apps with highest reviews kept)

# %%
android_clean = []
already_added = []

for app in google:
    name = app[0]
    n_reviews = float(app[3])
    
    if (reviews_max[name] == n_reviews) and (name not in already_added):
        android_clean.append(app)
        already_added.append(name)

# %%
explore_data(android_clean, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9659
# Number of columns: 13

# %% [markdown]
# ###### function to check whether app name is english

# %%
def is_english(string):
    non_ascii = 0
    
    for character in string:
        if ord(character) > 127:
            non_ascii += 1
    
    if non_ascii > 3:
        return False
    else:
        return True

print(is_english('Docs To Go™ Free Office Suite'))
print(is_english('Instachat 😜'))
# Out:
# True
# True

# %%
android_english = []
ios_english = []

for app in android_clean:
    name = app[0]
    if is_english(name):
        android_english.append(app)
        
for app in apple:
    name = app[1]
    if is_english(name):
        ios_english.append(app)
        
explore_data(android_english, 0, 3, True)
print('\n')
explore_data(ios_english, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 6183
# Number of columns: 16

# %% [markdown]
# ##### Isolate free apps in the datasets

# %%
android_free_eng = []
for each_row in android_english:
    price = each_row[7]
    if price == '0':
        android_free_eng.append(each_row)
        
ios_free_eng = []
for each_row in ios_english:
    price = float(each_row[4])
    if price == 0.0:
        ios_free_eng.append(each_row)

explore_data(android_free_eng, 0, 3, True)
print('\n')
explore_data(ios_free_eng, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 8864
# Number of columns: 13
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 3222
# Number of columns: 16

# %% [markdown]
# To minimize risks and overhead, our validation strategy for an app idea is comprised of three steps
# Build a minimal Android version of the app, and add it to Google Play.
# If the app has a good response from users, we develop it further.
# If the app is profitable after six months, we build an iOS version of the app and add it to the App Store.
#
# To find profiles that are successful on both markets (ios and play) we need to find most common genres in each market .

# %%
def freq_table(dataset, index):
    table = {}
    total = 0
    
    for row in dataset:
        total += 1
        value = row[index]
        if value in table:
            table[value] += 1
        else:
            table[value] = 1
    
    table_percentages = {}
    for key in table:
        percentage = (table[key] / total) * 100
        table_percentages[key] = percentage 
    
    return table_percentages


def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)
        
    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
display_table(ios_free_eng, -5)
# Out:
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %% [markdown]
# We can see that among the free English apps, more than a half (58.16%) are games. Entertainment apps are close to 8%, followed by photo and video apps, which are close to 5%. Only 3.66% of the apps are designed for education, followed by social networking apps which amount for 3.29% of the apps in our data set.
#
# The general impression is that App Store (atleast free english ones) is dominated by apps that are designed for fun (games, entertainment, photo and video, social networking, sports, music, etc.), while apps with practical purposes (education, shopping, utilities, productivity, lifestyle, etc.) are more rare. However, the fact that fun apps are the most numerous doesn't also imply that they also have the greatest number of users — the demand might not be the same as the offer.

# %%
# Category
display_table(android_free_eng, 1)
# Out:
# FAMILY : 18.907942238267147
# GAME : 9.724729241877256
# TOOLS : 8.461191335740072
# BUSINESS : 4.591606498194946
# LIFESTYLE : 3.9034296028880866
# PRODUCTIVITY : 3.892148014440433
# FINANCE : 3.7003610108303246
# MEDICAL : 3.531137184115524
# SPORTS : 3.395758122743682
# PERSONALIZATION : 3.3167870036101084
# COMMUNICATION : 3.2378158844765346
# HEALTH_AND_FITNESS : 3.0798736462093865
# PHOTOGRAPHY : 2.944494584837545
# NEWS_AND_MAGAZINES : 2.7978339350180503
# SOCIAL : 2.6624548736462095
# TRAVEL_AND_LOCAL : 2.33528880866426
# SHOPPING : 2.2450361010830324
# BOOKS_AND_REFERENCE : 2.1435018050541514
# DATING : 1.861462093862816
# VIDEO_PLAYERS : 1.7937725631768955
# MAPS_AND_NAVIGATION : 1.3989169675090252
# FOOD_AND_DRINK : 1.2409747292418771
# EDUCATION : 1.1620036101083033
# ENTERTAINMENT : 0.9589350180505415
# LIBRARIES_AND_DEMO : 0.9363718411552346
# AUTO_AND_VEHICLES : 0.9250902527075812
# HOUSE_AND_HOME : 0.8235559566787004
# WEATHER : 0.8009927797833934
# EVENTS : 0.7107400722021661
# PARENTING : 0.6543321299638989
# ART_AND_DESIGN : 0.6430505415162455
# COMICS : 0.6204873646209386
# BEAUTY : 0.5979241877256317

# %%
#genres 
display_table(android_free_eng, -4)
# Out:
# Tools : 8.449909747292418
# Entertainment : 6.069494584837545
# Education : 5.347472924187725
# Business : 4.591606498194946
# Productivity : 3.892148014440433
# Lifestyle : 3.892148014440433
# Finance : 3.7003610108303246
# Medical : 3.531137184115524
# Sports : 3.463447653429603
# Personalization : 3.3167870036101084
# Communication : 3.2378158844765346
# Action : 3.1024368231046933
# Health & Fitness : 3.0798736462093865
# Photography : 2.944494584837545
# News & Magazines : 2.7978339350180503
# Social : 2.6624548736462095
# Travel & Local : 2.3240072202166067
# Shopping : 2.2450361010830324
# Books & Reference : 2.1435018050541514
# Simulation : 2.0419675090252705
# Dating : 1.861462093862816
# Arcade : 1.8501805054151623
# Video Players & Editors : 1.7712093862815883
# Casual : 1.7599277978339352
# Maps & Navigation : 1.3989169675090252
# Food & Drink : 1.2409747292418771
# Puzzle : 1.128158844765343
# Racing : 0.9927797833935018
# Role Playing : 0.9363718411552346
# Libraries & Demo : 0.9363718411552346
# Auto & Vehicles : 0.9250902527075812
# Strategy : 0.9138086642599278
# House & Home : 0.8235559566787004
# Weather : 0.8009927797833934
# Events : 0.7107400722021661
# Adventure : 0.6768953068592057
# Comics : 0.6092057761732852
# Beauty : 0.5979241877256317
# Art & Design : 0.5979241877256317
# Parenting : 0.4963898916967509
# Card : 0.45126353790613716
# Casino : 0.42870036101083037
# Trivia : 0.41741877256317694
# Educational;Education : 0.39485559566787
# Board : 0.3835740072202166
# Educational : 0.3722924187725632
# Education;Education : 0.33844765342960287
# Word : 0.2594765342960289
# Casual;Pretend Play : 0.236913357400722
# Music : 0.2030685920577617
# Racing;Action & Adventure : 0.16922382671480143
# Puzzle;Brain Games : 0.16922382671480143
# Entertainment;Music & Video : 0.16922382671480143
# Casual;Brain Games : 0.13537906137184114
# Casual;Action & Adventure : 0.13537906137184114
# Arcade;Action & Adventure : 0.12409747292418773
# Action;Action & Adventure : 0.10153429602888085
# Educational;Pretend Play : 0.09025270758122744
# Simulation;Action & Adventure : 0.078971119133574
# Parenting;Education : 0.078971119133574
# Entertainment;Brain Games : 0.078971119133574
# Board;Brain Games : 0.078971119133574
# Parenting;Music & Video : 0.06768953068592057
# Educational;Brain Games : 0.06768953068592057
# Casual;Creativity : 0.06768953068592057
# Art & Design;Creativity : 0.06768953068592057
# Education;Pretend Play : 0.056407942238267145
# Role Playing;Pretend Play : 0.04512635379061372
# Education;Creativity : 0.04512635379061372
# Role Playing;Action & Adventure : 0.033844765342960284
# Puzzle;Action & Adventure : 0.033844765342960284
# Entertainment;Creativity : 0.033844765342960284
# Entertainment;Action & Adventure : 0.033844765342960284
# Educational;Creativity : 0.033844765342960284
# Educational;Action & Adventure : 0.033844765342960284
# Education;Music & Video : 0.033844765342960284
# Education;Brain Games : 0.033844765342960284
# Education;Action & Adventure : 0.033844765342960284
# Adventure;Action & Adventure : 0.033844765342960284
# Video Players & Editors;Music & Video : 0.02256317689530686
# Sports;Action & Adventure : 0.02256317689530686
# Simulation;Pretend Play : 0.02256317689530686
# Puzzle;Creativity : 0.02256317689530686
# Music;Music & Video : 0.02256317689530686
# Entertainment;Pretend Play : 0.02256317689530686
# Casual;Education : 0.02256317689530686
# Board;Action & Adventure : 0.02256317689530686
# Video Players & Editors;Creativity : 0.01128158844765343
# Trivia;Education : 0.01128158844765343
# Travel & Local;Action & Adventure : 0.01128158844765343
# Tools;Education : 0.01128158844765343
# Strategy;Education : 0.01128158844765343
# Strategy;Creativity : 0.01128158844765343
# Strategy;Action & Adventure : 0.01128158844765343
# Simulation;Education : 0.01128158844765343
# Role Playing;Brain Games : 0.01128158844765343
# Racing;Pretend Play : 0.01128158844765343
# Puzzle;Education : 0.01128158844765343
# Parenting;Brain Games : 0.01128158844765343
# Music & Audio;Music & Video : 0.01128158844765343
# Lifestyle;Pretend Play : 0.01128158844765343
# Lifestyle;Education : 0.01128158844765343
# Health & Fitness;Education : 0.01128158844765343
# Health & Fitness;Action & Adventure : 0.01128158844765343
# Entertainment;Education : 0.01128158844765343
# Communication;Creativity : 0.01128158844765343
# Comics;Creativity : 0.01128158844765343
# Casual;Music & Video : 0.01128158844765343
# Card;Action & Adventure : 0.01128158844765343
# Books & Reference;Education : 0.01128158844765343
# Art & Design;Pretend Play : 0.01128158844765343
# Art & Design;Action & Adventure : 0.01128158844765343
# Arcade;Pretend Play : 0.01128158844765343
# Adventure;Education : 0.01128158844765343

# %% [markdown]
# Category column more aptly conveys the type we need to assess the app profiles in Android
# We found that the App Store is dominated by apps designed for fun, while Google Play shows a more balanced landscape of both practical and for-fun apps(landscape dominated by FAMILY:19%,GAME:9.7%,TOOLS: 8.5%,BUSINESS:4.6% followed by LIFESTYLE and PRODUCTIVITY at approx 3.9%)

# %% [markdown]
# ### To determine the kind of Apps with most users
# #### Avg no of  installs for each app genre
#  * Android  : Installs column
#  * ios store: rating_count_tot column
# (No installs column so total number of user ratings taken as a proxy)

# %%
# prime_genre column 11/-5 of ios dataset 
genres_ios = freq_table(ios_free_eng, -5)
for genre in genres_ios:
    total = 0 # sum of(number of)user ratings specific to genre
    len_genre = 0  #no of apps specific to genre
    for app in ios_free_eng:
        genre_app = app[-5]
        if genre_app == genre:
            n_ratings = float(app[5]) #rating_count_tot col
            total += n_ratings
            len_genre += 1
    
    avg_n_ratings = total / len_genre
    print(genre, ':', avg_n_ratings)
# Out:
# Social Networking : 71548.34905660378
# Photo & Video : 28441.54375
# Games : 22788.6696905016
# Music : 57326.530303030304
# Reference : 74942.11111111111
# Health & Fitness : 23298.015384615384
# Weather : 52279.892857142855
# Utilities : 18684.456790123455
# Travel : 28243.8
# Shopping : 26919.690476190477
# News : 21248.023255813954
# Navigation : 86090.33333333333
# Lifestyle : 16485.764705882353
# Entertainment : 14029.830708661417
# Food & Drink : 33333.92307692308
# Sports : 23008.898550724636
# Book : 39758.5
# Finance : 31467.944444444445
# Education : 7003.983050847458
# Productivity : 21028.410714285714
# Business : 7491.117647058823
# Catalogs : 4004.0
# Medical : 612.0

# %% [markdown]
#  ## Most Popular Apps by Genre on Apple store
#  Navigation apps have the highest number of user ratings,followed by Reference and Social Networking.
# figures are influenced by few giants like
# * facebook ,pinterest skype (Social)
# *Waze and Google Maps (in Navigation)
# *Bible and Dictionary.com (in Reference)

# %%
popular = ['Navigation','Reference','Social Networking']
for genre in popular:
    for app in ios_free_eng: 
        if app[-5] == genre:
            print(app[-5],app[1],":",app[5])
# Out:
# Navigation Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Navigation Google Maps - Navigation & Transit : 154911
# Navigation Geocaching® : 12811
# Navigation CoPilot GPS – Car Navigation & Offline Maps : 3582
# Navigation ImmobilienScout24: Real Estate Search in Germany : 187
# Navigation Railway Route Search : 5
# Reference Bible : 985920
# Reference Dictionary.com Dictionary & Thesaurus : 200047
# Reference Dictionary.com Dictionary & Thesaurus for iPad : 54175
# Reference Google Translate : 26786
# Reference Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418
# Reference New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588
# Reference Merriam-Webster Dictionary : 16849
# Reference Night Sky : 12122
# Reference City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535
# Reference LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693
# Reference GUNS MODS for Minecraft PC Edition - Mods Tools : 1497
# Reference Guides for Pokémon GO - Pokemon GO News and Cheats : 826
# Reference WWDC : 762
# Reference Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718
# Reference VPN Express : 14
# Reference Real Bike Traffic Rider Virtual Reality Glasses : 8
# Reference 教えて!goo : 0
# Reference Jishokun-Japanese English Dictionary & Translator : 0
# Social Networking Facebook : 2974676
# Social Networking Pinterest : 1061624
# Social Networking Skype for iPhone : 373519
# Social Networking Messenger : 351466
# Social Networking Tumblr : 334293
# Social Networking WhatsApp Messenger : 287589
# Social Networking Kik : 260965
# Social Networking ooVoo – Free Video Call, Text and Voice : 177501
# Social Networking TextNow - Unlimited Text + Calls : 164963
# Social Networking Viber Messenger – Text & Call : 164249
# Social Networking Followers - Social Analytics For Instagram : 112778
# Social Networking MeetMe - Chat and Meet New People : 97072
# Social Networking We Heart It - Fashion, wallpapers, quotes, tattoos : 90414
# Social Networking InsTrack for Instagram - Analytics Plus More : 85535
# Social Networking Tango - Free Video Call, Voice and Chat : 75412
# Social Networking LinkedIn : 71856
# Social Networking Match™ - #1 Dating App. : 60659
# Social Networking Skype for iPad : 60163
# Social Networking POF - Best Dating App for Conversations : 52642
# Social Networking Timehop : 49510
# Social Networking Find My Family, Friends & iPhone - Life360 Locator : 43877
# Social Networking Whisper - Share, Express, Meet : 39819
# Social Networking Hangouts : 36404
# Social Networking LINE PLAY - Your Avatar World : 34677
# Social Networking WeChat : 34584
# Social Networking Badoo - Meet New People, Chat, Socialize. : 34428
# Social Networking Followers + for Instagram - Follower Analytics : 28633
# Social Networking GroupMe : 28260
# Social Networking Marco Polo Video Walkie Talkie : 27662
# Social Networking Miitomo : 23965
# Social Networking SimSimi : 23530
# Social Networking Grindr - Gay and same sex guys chat, meet and date : 23201
# Social Networking Wishbone - Compare Anything : 20649
# Social Networking imo video calls and chat : 18841
# Social Networking After School - Funny Anonymous School News : 18482
# Social Networking Quick Reposter - Repost, Regram and Reshare Photos : 17694
# Social Networking Weibo HD : 16772
# Social Networking Repost for Instagram : 15185
# Social Networking Live.me – Live Video Chat & Make Friends Nearby : 14724
# Social Networking Nextdoor : 14402
# Social Networking Followers Analytics for Instagram - InstaReport : 13914
# Social Networking YouNow: Live Stream Video Chat : 12079
# Social Networking FollowMeter for Instagram - Followers Tracking : 11976
# Social Networking LINE : 11437
# Social Networking eHarmony™ Dating App - Meet Singles : 11124
# Social Networking Discord - Chat for Gamers : 9152
# Social Networking QQ : 9109
# Social Networking Telegram Messenger : 7573
# Social Networking Weibo : 7265
# Social Networking Periscope - Live Video Streaming Around the World : 6062
# Social Networking Chat for Whatsapp - iPad Version : 5060
# Social Networking QQ HD : 5058
# Social Networking Followers Analysis Tool For Instagram App Free : 4253
# Social Networking live.ly - live video streaming : 4145
# Social Networking Houseparty - Group Video Chat : 3991
# Social Networking SOMA Messenger : 3232
# Social Networking Monkey : 3060
# Social Networking Down To Lunch : 2535
# Social Networking Flinch - Video Chat Staring Contest : 2134
# Social Networking Highrise - Your Avatar Community : 2011
# Social Networking LOVOO - Dating Chat : 1985
# Social Networking PlayStation®Messages : 1918
# Social Networking BOO! - Video chat camera with filters & stickers : 1805
# Social Networking Qzone : 1649
# Social Networking Chatous - Chat with new people : 1609
# Social Networking Kiwi - Q&A : 1538
# Social Networking GhostCodes - a discovery app for Snapchat : 1313
# Social Networking Jodel : 1193
# Social Networking FireChat : 1037
# Social Networking Google Duo - simple video calling : 1033
# Social Networking Fiesta by Tango - Chat & Meet New People : 885
# Social Networking Google Allo — smart messaging : 862
# Social Networking Peach — share vividly : 727
# Social Networking Hey! VINA - Where Women Meet New Friends : 719
# Social Networking Battlefield™ Companion : 689
# Social Networking All Devices for WhatsApp - Messenger for iPad : 682
# Social Networking Chat for Pokemon Go - GoChat : 500
# Social Networking IAmNaughty – Dating App to Meet New People Online : 463
# Social Networking Qzone HD : 458
# Social Networking Zenly - Locate your friends in realtime : 427
# Social Networking League of Legends Friends : 420
# Social Networking 豆瓣 : 407
# Social Networking Candid - Speak Your Mind Freely : 398
# Social Networking 知乎 : 397
# Social Networking Selfeo : 366
# Social Networking Fake-A-Location Free ™ : 354
# Social Networking Popcorn Buzz - Free Group Calls : 281
# Social Networking Fam — Group video calling for iMessage : 279
# Social Networking QQ International : 274
# Social Networking Ameba : 269
# Social Networking SoundCloud Pulse: for creators : 240
# Social Networking Tantan : 235
# Social Networking Cougar Dating & Life Style App for Mature Women : 213
# Social Networking Rawr Messenger - Dab your chat : 180
# Social Networking WhenToPost: Best Time to Post Photos for Instagram : 158
# Social Networking Inke—Broadcast an amazing life : 147
# Social Networking Mustknow - anonymous video Q&A : 53
# Social Networking CTFxCmoji : 39
# Social Networking Lobi : 36
# Social Networking Chain: Collaborate On MyVideo Story/Group Video : 35
# Social Networking botman - Real time video chat : 7
# Social Networking BestieBox : 0
# Social Networking MATCH ON LINE chat : 0
# Social Networking niconico ch : 0
# Social Networking LINE BLOG : 0
# Social Networking bit-tube - Live Stream Video Chat : 0

# %% [markdown]
# ## Most Popular Apps by Genre on Google Play

# %% [markdown]
# We have data about the number of installs for the Google Play market but  install numbers don't seem precise enough — values are open-ended (100+, 1,000+, 5,000+, etc)
# Since we just need the most attractive genres , precision is put on the back burner

# %%
display_table(android_free_eng, 5) # the Installs columns
# Out:
# 1,000,000+ : 15.726534296028879
# 100,000+ : 11.552346570397113
# 10,000,000+ : 10.548285198555957
# 10,000+ : 10.198555956678701
# 1,000+ : 8.393501805054152
# 100+ : 6.915613718411552
# 5,000,000+ : 6.825361010830325
# 500,000+ : 5.561823104693141
# 50,000+ : 4.7721119133574
# 5,000+ : 4.512635379061372
# 10+ : 3.5424187725631766
# 500+ : 3.2490974729241873
# 50,000,000+ : 2.3014440433213
# 100,000,000+ : 2.1322202166064983
# 50+ : 1.917870036101083
# 5+ : 0.78971119133574
# 1+ : 0.5076714801444043
# 500,000,000+ : 0.2707581227436823
# 1,000,000,000+ : 0.22563176895306858
# 0+ : 0.04512635379061372
# 0 : 0.01128158844765343

# %%
#category column 1 of google dataset
categories_android = freq_table(android_free_eng, 1)
genre_dict = {}
for category in categories_android:
    total = 0
    len_category = 0
    for app in android_free_eng:
        category_app = app[1]
        if category_app == category:            
            n_installs = app[5]
            n_installs = n_installs.replace(',', '')
            n_installs = n_installs.replace('+', '')
            total += float(n_installs)
            len_category += 1
    avg_n_installs = total / len_category
    

    print(category, ':', avg_n_installs)
    genre_dict[category] = avg_n_installs
# Out:
# ART_AND_DESIGN : 1986335.0877192982
# AUTO_AND_VEHICLES : 647317.8170731707
# BEAUTY : 513151.88679245283
# BOOKS_AND_REFERENCE : 8767811.894736841
# BUSINESS : 1712290.1474201474
# COMICS : 817657.2727272727
# COMMUNICATION : 38456119.167247385
# DATING : 854028.8303030303
# EDUCATION : 1833495.145631068
# ENTERTAINMENT : 11640705.88235294
# EVENTS : 253542.22222222222
# FINANCE : 1387692.475609756
# FOOD_AND_DRINK : 1924897.7363636363
# HEALTH_AND_FITNESS : 4188821.9853479853
# HOUSE_AND_HOME : 1331540.5616438356
# LIBRARIES_AND_DEMO : 638503.734939759
# LIFESTYLE : 1437816.2687861272
# GAME : 15588015.603248259
# FAMILY : 3695641.8198090694
# MEDICAL : 120550.61980830671
# SOCIAL : 23253652.127118643
# SHOPPING : 7036877.311557789
# PHOTOGRAPHY : 17840110.40229885
# SPORTS : 3638640.1428571427
# TRAVEL_AND_LOCAL : 13984077.710144928
# TOOLS : 10801391.298666667
# PERSONALIZATION : 5201482.6122448975
# PRODUCTIVITY : 16787331.344927534
# PARENTING : 542603.6206896552
# WEATHER : 5074486.197183099
# VIDEO_PLAYERS : 24727872.452830188
# NEWS_AND_MAGAZINES : 9549178.467741935
# MAPS_AND_NAVIGATION : 4056941.7741935486

# %%
genre_list = []
for key in genre_dict:
        key_val_as_tuple = (genre_dict[key], key)
        genre_list.append(key_val_as_tuple)
        genre_sorted = sorted(genre_list, reverse = True)
        
for entry in genre_sorted:
    print(entry[1], ':', entry[0])
# Out:
# COMMUNICATION : 38456119.167247385
# VIDEO_PLAYERS : 24727872.452830188
# SOCIAL : 23253652.127118643
# PHOTOGRAPHY : 17840110.40229885
# PRODUCTIVITY : 16787331.344927534
# GAME : 15588015.603248259
# TRAVEL_AND_LOCAL : 13984077.710144928
# ENTERTAINMENT : 11640705.88235294
# TOOLS : 10801391.298666667
# NEWS_AND_MAGAZINES : 9549178.467741935
# BOOKS_AND_REFERENCE : 8767811.894736841
# SHOPPING : 7036877.311557789
# PERSONALIZATION : 5201482.6122448975
# WEATHER : 5074486.197183099
# HEALTH_AND_FITNESS : 4188821.9853479853
# MAPS_AND_NAVIGATION : 4056941.7741935486
# FAMILY : 3695641.8198090694
# SPORTS : 3638640.1428571427
# ART_AND_DESIGN : 1986335.0877192982
# FOOD_AND_DRINK : 1924897.7363636363
# EDUCATION : 1833495.145631068
# BUSINESS : 1712290.1474201474
# LIFESTYLE : 1437816.2687861272
# FINANCE : 1387692.475609756
# HOUSE_AND_HOME : 1331540.5616438356
# DATING : 854028.8303030303
# COMICS : 817657.2727272727
# AUTO_AND_VEHICLES : 647317.8170731707
# LIBRARIES_AND_DEMO : 638503.734939759
# PARENTING : 542603.6206896552
# BEAUTY : 513151.88679245283
# EVENTS : 253542.22222222222
# MEDICAL : 120550.61980830671

# %% [markdown]
# Communication apps have the most installs: 38,456,119. This number is heavily skewed up by a few apps that have over one billion installs (WhatsApp, Facebook Messenger, Skype, Google Chrome, Gmail, and Hangouts)

# %%
popular = ['Communication','Video Players','Social','Photography']
for app in android_free_eng: 
    if app[1] == 'COMMUNICATION':
        print(app[1],app[0],":",app[5])
# Out:
# COMMUNICATION WhatsApp Messenger : 1,000,000,000+
# COMMUNICATION Messenger for SMS : 10,000,000+
# COMMUNICATION My Tele2 : 5,000,000+
# COMMUNICATION imo beta free calls and text : 100,000,000+
# COMMUNICATION Contacts : 50,000,000+
# COMMUNICATION Call Free – Free Call : 5,000,000+
# COMMUNICATION Web Browser & Explorer : 5,000,000+
# COMMUNICATION Browser 4G : 10,000,000+
# COMMUNICATION MegaFon Dashboard : 10,000,000+
# COMMUNICATION ZenUI Dialer & Contacts : 10,000,000+
# COMMUNICATION Cricket Visual Voicemail : 10,000,000+
# COMMUNICATION TracFone My Account : 1,000,000+
# COMMUNICATION Xperia Link™ : 10,000,000+
# COMMUNICATION TouchPal Keyboard - Fun Emoji & Android Keyboard : 10,000,000+
# COMMUNICATION Skype Lite - Free Video Call & Chat : 5,000,000+
# COMMUNICATION My magenta : 1,000,000+
# COMMUNICATION Android Messages : 100,000,000+
# COMMUNICATION Google Duo - High Quality Video Calls : 500,000,000+
# COMMUNICATION Seznam.cz : 1,000,000+
# COMMUNICATION Antillean Gold Telegram (original version) : 100,000+
# COMMUNICATION AT&T Visual Voicemail : 10,000,000+
# COMMUNICATION GMX Mail : 10,000,000+
# COMMUNICATION Omlet Chat : 10,000,000+
# COMMUNICATION My Vodacom SA : 5,000,000+
# COMMUNICATION Microsoft Edge : 5,000,000+
# COMMUNICATION Messenger – Text and Video Chat for Free : 1,000,000,000+
# COMMUNICATION imo free video calls and chat : 500,000,000+
# COMMUNICATION Calls & Text by Mo+ : 5,000,000+
# COMMUNICATION free video calls and chat : 50,000,000+
# COMMUNICATION Skype - free IM & video calls : 1,000,000,000+
# COMMUNICATION Who : 100,000,000+
# COMMUNICATION GO SMS Pro - Messenger, Free Themes, Emoji : 100,000,000+
# COMMUNICATION Messaging+ SMS, MMS Free : 1,000,000+
# COMMUNICATION chomp SMS : 10,000,000+
# COMMUNICATION Glide - Video Chat Messenger : 10,000,000+
# COMMUNICATION Text SMS : 10,000,000+
# COMMUNICATION Talkray - Free Calls & Texts : 10,000,000+
# COMMUNICATION LINE: Free Calls & Messages : 500,000,000+
# COMMUNICATION GroupMe : 10,000,000+
# COMMUNICATION mysms SMS Text Messaging Sync : 1,000,000+
# COMMUNICATION 2ndLine - Second Phone Number : 1,000,000+
# COMMUNICATION Google Chrome: Fast & Secure : 1,000,000,000+
# COMMUNICATION Firefox Browser fast & private : 100,000,000+
# COMMUNICATION Ninesky Browser : 1,000,000+
# COMMUNICATION Dolphin Browser - Fast, Private & Adblock🐬 : 50,000,000+
# COMMUNICATION UC Browser - Fast Download Private & Secure : 500,000,000+
# COMMUNICATION Ghostery Privacy Browser : 1,000,000+
# COMMUNICATION InBrowser - Incognito Browsing : 1,000,000+
# COMMUNICATION Lightning Web Browser : 500,000+
# COMMUNICATION Web Browser : 500,000+
# COMMUNICATION Contacts+ : 10,000,000+
# COMMUNICATION ExDialer - Dialer & Contacts : 10,000,000+
# COMMUNICATION PHONE for Google Voice & GTalk : 1,000,000+
# COMMUNICATION Safest Call Blocker : 1,000,000+
# COMMUNICATION Full Screen Caller ID : 5,000,000+
# COMMUNICATION Hiya - Caller ID & Block : 10,000,000+
# COMMUNICATION Mr. Number-Block calls & spam : 10,000,000+
# COMMUNICATION Should I Answer? : 1,000,000+
# COMMUNICATION RocketDial Dialer & Contacts : 1,000,000+
# COMMUNICATION CIA - Caller ID & Call Blocker : 5,000,000+
# COMMUNICATION Calls Blacklist - Call Blocker : 10,000,000+
# COMMUNICATION Call Control - Call Blocker : 5,000,000+
# COMMUNICATION True Contact - Real Caller ID : 1,000,000+
# COMMUNICATION Video Caller Id : 1,000,000+
# COMMUNICATION Sync.ME – Caller ID & Block : 5,000,000+
# COMMUNICATION Burner - Free Phone Number : 1,000,000+
# COMMUNICATION Caller ID + : 1,000,000+
# COMMUNICATION Gmail : 1,000,000,000+
# COMMUNICATION K-9 Mail : 5,000,000+
# COMMUNICATION myMail – Email for Hotmail, Gmail and Outlook Mail : 10,000,000+
# COMMUNICATION Email TypeApp - Mail App : 1,000,000+
# COMMUNICATION All Email Providers : 1,000,000+
# COMMUNICATION Newton Mail - Email App for Gmail, Outlook, IMAP : 1,000,000+
# COMMUNICATION GO Notifier : 10,000,000+
# COMMUNICATION Mail.Ru - Email App : 50,000,000+
# COMMUNICATION Mail1Click - Secure Mail : 10,000+
# COMMUNICATION Daum Mail - Next Mail : 5,000,000+
# COMMUNICATION mail.com mail : 1,000,000+
# COMMUNICATION SolMail - All-in-One email app : 500,000+
# COMMUNICATION Hangouts : 1,000,000,000+
# COMMUNICATION Vonage Mobile® Call Video Text : 1,000,000+
# COMMUNICATION JusTalk - Free Video Calls and Fun Video Chat : 5,000,000+
# COMMUNICATION Azar : 50,000,000+
# COMMUNICATION LokLok: Draw on a Lock Screen : 500,000+
# COMMUNICATION Discord - Chat for Gamers : 10,000,000+
# COMMUNICATION Messenger Lite: Free Calls & Messages : 100,000,000+
# COMMUNICATION AntennaPict β : 1,000,000+
# COMMUNICATION Talkatone: Free Texts, Calls & Phone Number : 10,000,000+
# COMMUNICATION Kik : 100,000,000+
# COMMUNICATION K-@ Mail - Email App : 100,000+
# COMMUNICATION KakaoTalk: Free Calls & Text : 100,000,000+
# COMMUNICATION K-9 Material (unofficial) : 5,000+
# COMMUNICATION M star Dialer : 100,000+
# COMMUNICATION Free WiFi Connect : 10,000,000+
# COMMUNICATION m:go BiH : 10,000+
# COMMUNICATION N-Com Wizard : 50,000+
# COMMUNICATION Opera Mini - fast web browser : 100,000,000+
# COMMUNICATION Opera Browser: Fast and Secure : 100,000,000+
# COMMUNICATION Opera Mini browser beta : 10,000,000+
# COMMUNICATION Psiphon Pro - The Internet Freedom VPN : 10,000,000+
# COMMUNICATION ICQ — Video Calls & Chat Messenger : 10,000,000+
# COMMUNICATION Telegram : 100,000,000+
# COMMUNICATION AT&T Messages for Tablet : 1,000,000+
# COMMUNICATION T-Mobile DIGITS : 100,000+
# COMMUNICATION Truecaller: Caller ID, SMS spam blocking & Dialer : 100,000,000+
# COMMUNICATION Portable Wi-Fi hotspot : 10,000,000+
# COMMUNICATION AT&T Call Protect : 5,000,000+
# COMMUNICATION U - Webinars, Meetings & Messenger : 500,000+
# COMMUNICATION UC Browser Mini -Tiny Fast Private & Secure : 100,000,000+
# COMMUNICATION /u/app : 10,000+
# COMMUNICATION [verify-U] VideoIdent : 10,000+
# COMMUNICATION Viber Messenger : 500,000,000+
# COMMUNICATION WeChat : 100,000,000+
# COMMUNICATION WhatsApp Business : 10,000,000+
# COMMUNICATION WhatsCall Free Global Phone Call App & Cheap Calls : 10,000,000+
# COMMUNICATION X Browser : 50,000+
# COMMUNICATION Yahoo Mail – Stay Organized : 100,000,000+
# COMMUNICATION Free Adblocker Browser - Adblock & Popup Blocker : 10,000,000+
# COMMUNICATION Adblock Browser for Android : 10,000,000+
# COMMUNICATION CM Browser - Ad Blocker , Fast Download , Privacy : 50,000,000+
# COMMUNICATION Adblock Plus for Samsung Internet - Browse safe. : 1,000,000+
# COMMUNICATION Ad Blocker Turbo - Adblocker Browser : 10,000+
# COMMUNICATION Brave Browser: Fast AdBlocker : 5,000,000+
# COMMUNICATION AG Contacts, Lite edition : 5,000+
# COMMUNICATION Oklahoma Ag Co-op Council : 10+
# COMMUNICATION Bee'ah Employee App : 100+
# COMMUNICATION tournaments and more.aj.2 : 100+
# COMMUNICATION Aj.Petra : 100+
# COMMUNICATION AK Phone : 5,000+
# COMMUNICATION PlacarTv Futebol Ao Vivo : 100,000+
# COMMUNICATION WiFi Access Point (hotspot) : 100,000+
# COMMUNICATION Access Point Names : 10,000+
# COMMUNICATION Puffin Web Browser : 10,000,000+
# COMMUNICATION ClanHQ : 10,000+
# COMMUNICATION Ear Agent: Super Hearing : 5,000,000+
# COMMUNICATION Google Voice : 10,000,000+
# COMMUNICATION Google Allo : 10,000,000+
# COMMUNICATION AU Call Blocker - Block Unwanted Calls Texts 2018 : 1,000+
# COMMUNICATION Baby Monitor AV : 100,000+
# COMMUNICATION AV Phone : 1,000+
# COMMUNICATION AW - free video calls and chat : 1,000,000+
# COMMUNICATION Katalogen.ax : 100+
# COMMUNICATION AZ Browser. Private & Download : 100,000+
# COMMUNICATION BA SALES : 1+
# COMMUNICATION BD Data Plan (3G & 4G) : 500,000+
# COMMUNICATION BD Internet Packages (Updated) : 50,000+
# COMMUNICATION BD Dialer : 10,000+
# COMMUNICATION BD Live Call : 5,000+
# COMMUNICATION Best Browser BD social networking : 10+
# COMMUNICATION Traffic signs BD : 500+
# COMMUNICATION BF Browser by Betfilter - Stop Gambling Today! : 10,000+
# COMMUNICATION My BF App : 50,000+
# COMMUNICATION BH Mail : 1,000+
# COMMUNICATION Zalo – Video Call : 50,000,000+
# COMMUNICATION BJ - Confidential : 10+
# COMMUNICATION BK Chat : 1,000+
# COMMUNICATION Of the wall Arapaho bk : 5+
# COMMUNICATION AC-BL : 50+
# COMMUNICATION BBM - Free Calls & Messages : 100,000,000+
# COMMUNICATION DMR BrandMeister Tool : 10,000+
# COMMUNICATION BBMoji - Your personalized BBM Stickers : 1,000,000+
# COMMUNICATION BN MALLORCA Radio : 1,000+
# COMMUNICATION BQ Partners : 1,000+
# COMMUNICATION BS-Mobile : 50+
# COMMUNICATION ATC Unico BS : 500+
# COMMUNICATION BT One Voice mobile access : 5,000+
# COMMUNICATION BT Messenger : 50,000+
# COMMUNICATION BT One Phone Mobile App : 10,000+
# COMMUNICATION SW-100.tch by Callstel : 1,000,000+
# COMMUNICATION BT MeetMe with Dolby Voice : 100,000+
# COMMUNICATION Bluetooth Auto Connect : 5,000,000+
# COMMUNICATION AudioBT: BT audio GPS/SMS/Text : 50,000+
# COMMUNICATION BV : 100+
# COMMUNICATION Feel Performer : 10,000+
# COMMUNICATION Tiny Call Confirm : 1,000,000+
# COMMUNICATION CB Radio Chat - for friends! : 1,000,000+
# COMMUNICATION CB On Mobile : 100,000+
# COMMUNICATION Virtual Walkie Talkie : 1,000,000+
# COMMUNICATION Channel 19 : 100,000+
# COMMUNICATION Cb browser : 50+
# COMMUNICATION CF Chat: Connecting Friends : 100+
# COMMUNICATION retteMi.ch : 5,000+
# COMMUNICATION Chrome Dev : 5,000,000+
# COMMUNICATION CJ Browser - Fast & Private : 100+
# COMMUNICATION CJ DVD Rentals : 100+
# COMMUNICATION CK Call NEW : 10+
# COMMUNICATION CM Transfer - Share any files with friends nearby : 5,000,000+
# COMMUNICATION mail.co.uk Mail : 5,000+
# COMMUNICATION ClanPlay: Community and Tools for Gamers : 1,000,000+
# COMMUNICATION CQ-Mobile : 1,000+
# COMMUNICATION CQ-Alert : 500+
# COMMUNICATION QRZ Assistant : 100,000+
# COMMUNICATION Pocket Prefix Plus : 10,000+
# COMMUNICATION Ham Radio Prefixes : 10,000+
# COMMUNICATION CS Customizer : 1,000+
# COMMUNICATION CS Browser | #1 & BEST BROWSER : 1,000+
# COMMUNICATION CS Browser Beta : 5,000+
# COMMUNICATION My Vodafone (GR) : 1,000,000+
# COMMUNICATION IZ2UUF Morse Koch CW : 50,000+
# COMMUNICATION C W Browser : 100+
# COMMUNICATION CW Bluetooth SPP : 100+
# COMMUNICATION CW BLE Peripheral Simulator : 500+
# COMMUNICATION Morse Code Reader : 100,000+
# COMMUNICATION Learn Morse Code - G0HYN Learn Morse : 5,000+
# COMMUNICATION Ring : 10,000+
# COMMUNICATION Hyundai CX Conference : 50+
# COMMUNICATION Cy Messenger : 100+
# COMMUNICATION Amadeus GR & CY : 100+
# COMMUNICATION Hlášenírozhlasu.cz : 10+
# COMMUNICATION SMS Sender - sluzba.cz : 1,000+
# COMMUNICATION WEB.DE Mail : 10,000,000+
# COMMUNICATION Your Freedom VPN Client : 5,000,000+
# COMMUNICATION CallApp: Caller ID, Blocker & Phone Call Recorder : 10,000,000+
# COMMUNICATION Rádio Sol Nascente DF : 500+
# COMMUNICATION DG Card : 100+
# COMMUNICATION Whoscall - Caller ID & Block : 10,000,000+
# COMMUNICATION DK Browser : 10+
# COMMUNICATION cluster.dk : 1,000+
# COMMUNICATION DK TEL Dialer : 50+
# COMMUNICATION DM for WhatsApp : 5,000+
# COMMUNICATION DM Talk New : 5,000+
# COMMUNICATION DM - The Offical Messaging App : 10+
# COMMUNICATION DM Tracker : 1,000+
# COMMUNICATION Call Blocker & Blacklist : 1,000+
# COMMUNICATION ReadyOp DT : 1,000+
# COMMUNICATION DU Browser—Browse fast & fun : 10,000,000+
# COMMUNICATION Caller ID & Call Block - DU Caller : 5,000,000+
# COMMUNICATION BlueDV AMBE : 1,000+
# COMMUNICATION DW Contacts & Phone & Dialer : 1,000,000+
# COMMUNICATION Deaf World DW : 10,000+
# COMMUNICATION Ham DX Cluster & Spots Finder : 5,000+
# COMMUNICATION Mircules DX Cluster Lite : 5,000+
# COMMUNICATION 3G DZ Configuration : 50,000+
# COMMUNICATION chat dz : 100+
# COMMUNICATION love sms good morning : 5,000+
# COMMUNICATION Goodbox - Mega App : 100,000+
# COMMUNICATION Call Blocker - Blacklist, SMS Blocker : 1,000,000+
# COMMUNICATION [EF]ShoutBox : 100+
# COMMUNICATION Eg Call : 10,000+
# COMMUNICATION ei : 10+
# COMMUNICATION EJ messenger : 10+
# COMMUNICATION Ek IRA : 10+
# COMMUNICATION Orfox: Tor Browser for Android : 10,000,000+
# COMMUNICATION EO Mumbai : 10+
# COMMUNICATION EP RSS Reader : 100+
# COMMUNICATION Voxer Walkie Talkie Messenger : 10,000,000+
# COMMUNICATION ES-1 : 500+
# COMMUNICATION Hangouts Dialer - Call Phones : 10,000,000+
# COMMUNICATION EU Council : 1,000+
# COMMUNICATION Council Voting Calculator : 5,000+
# COMMUNICATION Have your say on Europe : 500+
# COMMUNICATION Programi podrške EU : 100+
# COMMUNICATION Inbox.eu : 10,000+
# COMMUNICATION Web Browser for Android : 1,000,000+
# COMMUNICATION Everbridge : 100,000+
# COMMUNICATION Best Auto Call Recorder Free : 500+
# COMMUNICATION EZ Wifi Notification : 10,000+
# COMMUNICATION Test Server SMS FA : 5+
# COMMUNICATION Lite for Facebook Messenger : 1,000,000+
# COMMUNICATION FC Browser - Focus Privacy Browser : 1,000+
# COMMUNICATION EHiN-FH conferenceapp : 100+
# COMMUNICATION Carpooling FH Hagenberg : 100+
# COMMUNICATION Wi-Fi Auto-connect : 1,000,000+
# COMMUNICATION Talkie - Wi-Fi Calling, Chats, File Sharing : 500,000+
# COMMUNICATION WeFi - Free Fast WiFi Connect & Find Wi-Fi Map : 1,000,000+
# COMMUNICATION Sat-Fi : 5,000+
# COMMUNICATION Portable Wi-Fi hotspot Free : 100,000+
# COMMUNICATION TownWiFi | Wi-Fi Everywhere : 500,000+
# COMMUNICATION Jazz Wi-Fi : 10,000+
# COMMUNICATION Sat-Fi Voice : 1,000+
# COMMUNICATION Free Wi-fi HotspoT : 50,000+
# COMMUNICATION FN Web Radio : 10+
# COMMUNICATION FNH Payment Info : 10+
# COMMUNICATION MARKET FO : 100+
# COMMUNICATION FO OP St-Nazaire : 100+
# COMMUNICATION FO SODEXO : 100+
# COMMUNICATION FO RCBT : 100+
# COMMUNICATION FO Interim : 100+
# COMMUNICATION FO PSA Sept-Fons : 100+
# COMMUNICATION FO AIRBUS TLSE : 1,000+
# COMMUNICATION FO STELIA Méaulte : 100+
# COMMUNICATION FO AIRBUS Nantes : 100+
# COMMUNICATION Firefox Focus: The privacy browser : 1,000,000+
# COMMUNICATION FP Connect : 100+
# COMMUNICATION FreedomPop Messaging Phone/SIM : 500,000+
# COMMUNICATION FP Live : 10+
# COMMUNICATION HipChat - beta version : 50,000+

# %% [markdown]
# The market is dominated by apps like Youtube, Google Play Movies & TV, or MX Player. The pattern is repeated for social apps (where we have giants like Facebook, Instagram, Google+, etc.), photography apps (Google Photos and other popular photo editors), or productivity apps (Microsoft Word, Dropbox, Google Calendar, Evernote, etc.)

# %% [markdown]
# The books and reference genre looks fairly popular as well, with an average number of installs of 8,767,811 . The aim is to recommend an app genre that shows potential for being profitable on both the App Store and Google Play.

# %%
final_dict = {}
for app in android_free_eng: 
    if app[1] == 'BOOKS_AND_REFERENCE':
        print(app[1],app[0],":",app[5])
        final_dict[app[0]] = app[5]
# Out:
# BOOKS_AND_REFERENCE E-Book Read - Read Book for free : 50,000+
# BOOKS_AND_REFERENCE Download free book with green book : 100,000+
# BOOKS_AND_REFERENCE Wikipedia : 10,000,000+
# BOOKS_AND_REFERENCE Cool Reader : 10,000,000+
# BOOKS_AND_REFERENCE Free Panda Radio Music : 100,000+
# BOOKS_AND_REFERENCE Book store : 1,000,000+
# BOOKS_AND_REFERENCE FBReader: Favorite Book Reader : 10,000,000+
# BOOKS_AND_REFERENCE English Grammar Complete Handbook : 500,000+
# BOOKS_AND_REFERENCE Free Books - Spirit Fanfiction and Stories : 1,000,000+
# BOOKS_AND_REFERENCE Google Play Books : 1,000,000,000+
# BOOKS_AND_REFERENCE AlReader -any text book reader : 5,000,000+
# BOOKS_AND_REFERENCE Offline English Dictionary : 100,000+
# BOOKS_AND_REFERENCE Offline: English to Tagalog Dictionary : 500,000+
# BOOKS_AND_REFERENCE FamilySearch Tree : 1,000,000+
# BOOKS_AND_REFERENCE Cloud of Books : 1,000,000+
# BOOKS_AND_REFERENCE Recipes of Prophetic Medicine for free : 500,000+
# BOOKS_AND_REFERENCE ReadEra – free ebook reader : 1,000,000+
# BOOKS_AND_REFERENCE Anonymous caller detection : 10,000+
# BOOKS_AND_REFERENCE Ebook Reader : 5,000,000+
# BOOKS_AND_REFERENCE Litnet - E-books : 100,000+
# BOOKS_AND_REFERENCE Read books online : 5,000,000+
# BOOKS_AND_REFERENCE English to Urdu Dictionary : 500,000+
# BOOKS_AND_REFERENCE eBoox: book reader fb2 epub zip : 1,000,000+
# BOOKS_AND_REFERENCE English Persian Dictionary : 500,000+
# BOOKS_AND_REFERENCE Flybook : 500,000+
# BOOKS_AND_REFERENCE All Maths Formulas : 1,000,000+
# BOOKS_AND_REFERENCE Ancestry : 5,000,000+
# BOOKS_AND_REFERENCE HTC Help : 10,000,000+
# BOOKS_AND_REFERENCE English translation from Bengali : 100,000+
# BOOKS_AND_REFERENCE Pdf Book Download - Read Pdf Book : 100,000+
# BOOKS_AND_REFERENCE Free Book Reader : 100,000+
# BOOKS_AND_REFERENCE eBoox new: Reader for fb2 epub zip books : 50,000+
# BOOKS_AND_REFERENCE Only 30 days in English, the guideline is guaranteed : 500,000+
# BOOKS_AND_REFERENCE Moon+ Reader : 10,000,000+
# BOOKS_AND_REFERENCE SH-02J Owner's Manual (Android 8.0) : 50,000+
# BOOKS_AND_REFERENCE English-Myanmar Dictionary : 1,000,000+
# BOOKS_AND_REFERENCE Golden Dictionary (EN-AR) : 1,000,000+
# BOOKS_AND_REFERENCE All Language Translator Free : 1,000,000+
# BOOKS_AND_REFERENCE Azpen eReader : 500,000+
# BOOKS_AND_REFERENCE URBANO V 02 instruction manual : 100,000+
# BOOKS_AND_REFERENCE Bible : 100,000,000+
# BOOKS_AND_REFERENCE C Programs and Reference : 50,000+
# BOOKS_AND_REFERENCE C Offline Tutorial : 1,000+
# BOOKS_AND_REFERENCE C Programs Handbook : 50,000+
# BOOKS_AND_REFERENCE Amazon Kindle : 100,000,000+
# BOOKS_AND_REFERENCE Aab e Hayat Full Novel : 100,000+
# BOOKS_AND_REFERENCE Aldiko Book Reader : 10,000,000+
# BOOKS_AND_REFERENCE Google I/O 2018 : 500,000+
# BOOKS_AND_REFERENCE R Language Reference Guide : 10,000+
# BOOKS_AND_REFERENCE Learn R Programming Full : 5,000+
# BOOKS_AND_REFERENCE R Programing Offline Tutorial : 1,000+
# BOOKS_AND_REFERENCE Guide for R Programming : 5+
# BOOKS_AND_REFERENCE Learn R Programming : 10+
# BOOKS_AND_REFERENCE R Quick Reference Big Data : 1,000+
# BOOKS_AND_REFERENCE V Made : 100,000+
# BOOKS_AND_REFERENCE Wattpad 📖 Free Books : 100,000,000+
# BOOKS_AND_REFERENCE Dictionary - WordWeb : 5,000,000+
# BOOKS_AND_REFERENCE Guide (for X-MEN) : 100,000+
# BOOKS_AND_REFERENCE AC Air condition Troubleshoot,Repair,Maintenance : 5,000+
# BOOKS_AND_REFERENCE AE Bulletins : 1,000+
# BOOKS_AND_REFERENCE Ae Allah na Dai (Rasa) : 10,000+
# BOOKS_AND_REFERENCE 50000 Free eBooks & Free AudioBooks : 5,000,000+
# BOOKS_AND_REFERENCE Ag PhD Field Guide : 10,000+
# BOOKS_AND_REFERENCE Ag PhD Deficiencies : 10,000+
# BOOKS_AND_REFERENCE Ag PhD Planting Population Calculator : 1,000+
# BOOKS_AND_REFERENCE Ag PhD Soybean Diseases : 1,000+
# BOOKS_AND_REFERENCE Fertilizer Removal By Crop : 50,000+
# BOOKS_AND_REFERENCE A-J Media Vault : 50+
# BOOKS_AND_REFERENCE Al-Quran (Free) : 10,000,000+
# BOOKS_AND_REFERENCE Al Quran (Tafsir & by Word) : 500,000+
# BOOKS_AND_REFERENCE Al Quran Indonesia : 10,000,000+
# BOOKS_AND_REFERENCE Al'Quran Bahasa Indonesia : 10,000,000+
# BOOKS_AND_REFERENCE Al Quran Al karim : 1,000,000+
# BOOKS_AND_REFERENCE Al-Muhaffiz : 50,000+
# BOOKS_AND_REFERENCE Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# BOOKS_AND_REFERENCE Al-Quran 30 Juz free copies : 500,000+
# BOOKS_AND_REFERENCE Koran Read &MP3 30 Juz Offline : 1,000,000+
# BOOKS_AND_REFERENCE Hafizi Quran 15 lines per page : 1,000,000+
# BOOKS_AND_REFERENCE Quran for Android : 10,000,000+
# BOOKS_AND_REFERENCE Surah Al-Waqiah : 100,000+
# BOOKS_AND_REFERENCE Hisnul Al Muslim - Hisn Invocations & Adhkaar : 100,000+
# BOOKS_AND_REFERENCE Satellite AR : 1,000,000+
# BOOKS_AND_REFERENCE Audiobooks from Audible : 100,000,000+
# BOOKS_AND_REFERENCE Kinot & Eichah for Tisha B'Av : 10,000+
# BOOKS_AND_REFERENCE AW Tozer Devotionals - Daily : 5,000+
# BOOKS_AND_REFERENCE Tozer Devotional -Series 1 : 1,000+
# BOOKS_AND_REFERENCE The Pursuit of God : 1,000+
# BOOKS_AND_REFERENCE AY Sing : 5,000+
# BOOKS_AND_REFERENCE Ay Hasnain k Nana Milad Naat : 10,000+
# BOOKS_AND_REFERENCE Ay Mohabbat Teri Khatir Novel : 10,000+
# BOOKS_AND_REFERENCE Arizona Statutes, ARS (AZ Law) : 1,000+
# BOOKS_AND_REFERENCE Oxford A-Z of English Usage : 1,000,000+
# BOOKS_AND_REFERENCE BD Fishpedia : 1,000+
# BOOKS_AND_REFERENCE BD All Sim Offer : 10,000+
# BOOKS_AND_REFERENCE Youboox - Livres, BD et magazines : 500,000+
# BOOKS_AND_REFERENCE B&H Kids AR : 10,000+
# BOOKS_AND_REFERENCE B y H Niños ES : 5,000+
# BOOKS_AND_REFERENCE Dictionary.com: Find Definitions for English Words : 10,000,000+
# BOOKS_AND_REFERENCE English Dictionary - Offline : 10,000,000+
# BOOKS_AND_REFERENCE Bible KJV : 5,000,000+
# BOOKS_AND_REFERENCE Borneo Bible, BM Bible : 10,000+
# BOOKS_AND_REFERENCE MOD Black for BM : 100+
# BOOKS_AND_REFERENCE BM Box : 1,000+
# BOOKS_AND_REFERENCE Anime Mod for BM : 100+
# BOOKS_AND_REFERENCE NOOK: Read eBooks & Magazines : 10,000,000+
# BOOKS_AND_REFERENCE NOOK Audiobooks : 500,000+
# BOOKS_AND_REFERENCE NOOK App for NOOK Devices : 500,000+
# BOOKS_AND_REFERENCE Browsery by Barnes & Noble : 5,000+
# BOOKS_AND_REFERENCE bp e-store : 1,000+
# BOOKS_AND_REFERENCE Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# BOOKS_AND_REFERENCE BR Ambedkar Biography & Quotes : 10,000+
# BOOKS_AND_REFERENCE BU Alsace : 100+
# BOOKS_AND_REFERENCE Catholic La Bu Zo Kam : 500+
# BOOKS_AND_REFERENCE Khrifa Hla Bu (Solfa) : 10+
# BOOKS_AND_REFERENCE Kristian Hla Bu : 10,000+
# BOOKS_AND_REFERENCE SA HLA BU : 1,000+
# BOOKS_AND_REFERENCE Learn SAP BW : 500+
# BOOKS_AND_REFERENCE Learn SAP BW on HANA : 500+
# BOOKS_AND_REFERENCE CA Laws 2018 (California Laws and Codes) : 5,000+
# BOOKS_AND_REFERENCE Bootable Methods(USB-CD-DVD) : 10,000+
# BOOKS_AND_REFERENCE cloudLibrary : 100,000+
# BOOKS_AND_REFERENCE SDA Collegiate Quarterly : 500+
# BOOKS_AND_REFERENCE Sabbath School : 100,000+
# BOOKS_AND_REFERENCE Cypress College Library : 100+
# BOOKS_AND_REFERENCE Stats Royale for Clash Royale : 1,000,000+
# BOOKS_AND_REFERENCE GATE 21 years CS Papers(2011-2018 Solved) : 50+
# BOOKS_AND_REFERENCE Learn CT Scan Of Head : 5,000+
# BOOKS_AND_REFERENCE Easy Cv maker 2018 : 10,000+
# BOOKS_AND_REFERENCE How to Write CV : 100,000+
# BOOKS_AND_REFERENCE CW Nuclear : 1,000+
# BOOKS_AND_REFERENCE CY Spray nozzle : 10+
# BOOKS_AND_REFERENCE BibleRead En Cy Zh Yue : 5+
# BOOKS_AND_REFERENCE CZ-Help : 5+
# BOOKS_AND_REFERENCE Modlitební knížka CZ : 500+
# BOOKS_AND_REFERENCE Guide for DB Xenoverse : 10,000+
# BOOKS_AND_REFERENCE Guide for DB Xenoverse 2 : 10,000+
# BOOKS_AND_REFERENCE Guide for IMS DB : 10+
# BOOKS_AND_REFERENCE DC HSEMA : 5,000+
# BOOKS_AND_REFERENCE DC Public Library : 1,000+
# BOOKS_AND_REFERENCE Painting Lulu DC Super Friends : 1,000+
# BOOKS_AND_REFERENCE Dictionary : 10,000,000+
# BOOKS_AND_REFERENCE Fix Error Google Playstore : 1,000+
# BOOKS_AND_REFERENCE D. H. Lawrence Poems FREE : 1,000+
# BOOKS_AND_REFERENCE Bilingual Dictionary Audio App : 5,000+
# BOOKS_AND_REFERENCE DM Screen : 10,000+
# BOOKS_AND_REFERENCE wikiHow: how to do anything : 1,000,000+
# BOOKS_AND_REFERENCE Dr. Doug's Tips : 1,000+
# BOOKS_AND_REFERENCE Bible du Semeur-BDS (French) : 50,000+
# BOOKS_AND_REFERENCE La citadelle du musulman : 50,000+
# BOOKS_AND_REFERENCE DV 2019 Entry Guide : 10,000+
# BOOKS_AND_REFERENCE DV 2019 - EDV Photo & Form : 50,000+
# BOOKS_AND_REFERENCE DV 2018 Winners Guide : 1,000+
# BOOKS_AND_REFERENCE EB Annual Meetings : 1,000+
# BOOKS_AND_REFERENCE EC - AP & Telangana : 5,000+
# BOOKS_AND_REFERENCE TN Patta Citta & EC : 10,000+
# BOOKS_AND_REFERENCE AP Stamps and Registration : 10,000+
# BOOKS_AND_REFERENCE CompactiMa EC pH Calibration : 100+
# BOOKS_AND_REFERENCE EGW Writings 2 : 100,000+
# BOOKS_AND_REFERENCE EGW Writings : 1,000,000+
# BOOKS_AND_REFERENCE Bible with EGW Comments : 100,000+
# BOOKS_AND_REFERENCE My Little Pony AR Guide : 1,000,000+
# BOOKS_AND_REFERENCE SDA Sabbath School Quarterly : 500,000+
# BOOKS_AND_REFERENCE Duaa Ek Ibaadat : 5,000+
# BOOKS_AND_REFERENCE Spanish English Translator : 10,000,000+
# BOOKS_AND_REFERENCE Dictionary - Merriam-Webster : 10,000,000+
# BOOKS_AND_REFERENCE JW Library : 10,000,000+
# BOOKS_AND_REFERENCE Oxford Dictionary of English : Free : 10,000,000+
# BOOKS_AND_REFERENCE English Hindi Dictionary : 10,000,000+
# BOOKS_AND_REFERENCE English to Hindi Dictionary : 5,000,000+
# BOOKS_AND_REFERENCE EP Research Service : 1,000+
# BOOKS_AND_REFERENCE Hymnes et Louanges : 100,000+
# BOOKS_AND_REFERENCE EU Charter : 1,000+
# BOOKS_AND_REFERENCE EU Data Protection : 1,000+
# BOOKS_AND_REFERENCE EU IP Codes : 100+
# BOOKS_AND_REFERENCE EW PDF : 5+
# BOOKS_AND_REFERENCE BakaReader EX : 100,000+
# BOOKS_AND_REFERENCE EZ Quran : 50,000+
# BOOKS_AND_REFERENCE FA Part 1 & 2 Past Papers Solved Free – Offline : 5,000+
# BOOKS_AND_REFERENCE La Fe de Jesus : 1,000+
# BOOKS_AND_REFERENCE La Fe de Jesús : 500+
# BOOKS_AND_REFERENCE Le Fe de Jesus : 500+
# BOOKS_AND_REFERENCE Florida - Pocket Brainbook : 1,000+
# BOOKS_AND_REFERENCE Florida Statutes (FL Code) : 1,000+
# BOOKS_AND_REFERENCE English To Shona Dictionary : 10,000+
# BOOKS_AND_REFERENCE Greek Bible FP (Audio) : 1,000+
# BOOKS_AND_REFERENCE Golden Dictionary (FR-AR) : 500,000+
# BOOKS_AND_REFERENCE Fanfic-FR : 5,000+
# BOOKS_AND_REFERENCE Bulgarian French Dictionary Fr : 10,000+
# BOOKS_AND_REFERENCE Chemin (fr) : 1,000+
# BOOKS_AND_REFERENCE The SCP Foundation DB fr nn5n : 1,000+

# %%
tmp = []
for k,v in final_dict.items():
    tmp.append((v,k))
    
    
print("Descending order of installs :",sorted(tmp[:50],reverse = True))
# Out:
# Descending order of installs : [('500,000+', 'Recipes of Prophetic Medicine for free'), ('500,000+', 'Only 30 days in English, the guideline is guaranteed'), ('500,000+', 'Offline: English to Tagalog Dictionary'), ('500,000+', 'Google I/O 2018'), ('500,000+', 'Flybook'), ('500,000+', 'English to Urdu Dictionary'), ('500,000+', 'English Persian Dictionary'), ('500,000+', 'English Grammar Complete Handbook'), ('500,000+', 'Azpen eReader'), ('50,000+', 'eBoox new: Reader for fb2 epub zip books'), ('50,000+', "SH-02J Owner's Manual (Android 8.0)"), ('50,000+', 'E-Book Read - Read Book for free'), ('50,000+', 'C Programs and Reference'), ('50,000+', 'C Programs Handbook'), ('5,000,000+', 'Read books online'), ('5,000,000+', 'Ebook Reader'), ('5,000,000+', 'Ancestry'), ('5,000,000+', 'AlReader -any text book reader'), ('5,000+', 'Learn R Programming Full'), ('100,000,000+', 'Bible'), ('100,000,000+', 'Amazon Kindle'), ('100,000+', 'URBANO V 02 instruction manual'), ('100,000+', 'Pdf Book Download - Read Pdf Book'), ('100,000+', 'Offline English Dictionary'), ('100,000+', 'Litnet - E-books'), ('100,000+', 'Free Panda Radio Music'), ('100,000+', 'Free Book Reader'), ('100,000+', 'English translation from Bengali'), ('100,000+', 'Download free book with green book'), ('100,000+', 'Aab e Hayat Full Novel'), ('10,000,000+', 'Wikipedia'), ('10,000,000+', 'Moon+ Reader'), ('10,000,000+', 'HTC Help'), ('10,000,000+', 'FBReader: Favorite Book Reader'), ('10,000,000+', 'Cool Reader'), ('10,000,000+', 'Aldiko Book Reader'), ('10,000+', 'R Language Reference Guide'), ('10,000+', 'Anonymous caller detection'), ('1,000,000,000+', 'Google Play Books'), ('1,000,000+', 'eBoox: book reader fb2 epub zip'), ('1,000,000+', 'ReadEra – free ebook reader'), ('1,000,000+', 'Golden Dictionary (EN-AR)'), ('1,000,000+', 'Free Books - Spirit Fanfiction and Stories'), ('1,000,000+', 'FamilySearch Tree'), ('1,000,000+', 'English-Myanmar Dictionary'), ('1,000,000+', 'Cloud of Books'), ('1,000,000+', 'Book store'), ('1,000,000+', 'All Maths Formulas'), ('1,000,000+', 'All Language Translator Free'), ('1,000+', 'C Offline Tutorial')]

# %% [markdown]
# ### Conclusion
# This niche seems to be dominated by software for processing and reading ebooks, as well as various collections of libraries and dictionaries, so it's probably not a good idea to build similar apps since there'll be some significant competition.
#
#
# Building an app around a popular book can be profitable. It seems that taking a popular book (perhaps a more recent book) and turning it into an app could be profitable for both the Google Play and the App Store markets.
# Some gamification or peer discussion might be beneficial which can include quotes , character profiles/graphics etc
